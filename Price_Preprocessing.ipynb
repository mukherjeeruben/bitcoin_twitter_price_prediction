# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
from textblob import TextBlob

# %%
tweets = pd.read_csv("tweets.csv")

# %%
len(tweets)
# Out:
# 2573255

# %%
tweets.head(5)
# Out:
#                   date                                               text
# 0  2021-02-10 23:59:04  Blue Ridge Bank shares halted by NYSE after #b...
# 1  2021-02-10 23:58:48  😎 Today, that's this #Thursday, we will do a "...
# 2  2021-02-10 23:54:48  Guys evening, I have read this article about B...
# 3  2021-02-10 23:54:33  $BTC A big chance in a billion! Price: \487264...
# 4  2021-02-10 23:54:06  This network is secured by 9 508 nodes as of t...

# %%
del tweets["user_favourites"]
del tweets["user_location"]
del tweets["user_description"]
del tweets["user_created"]
del tweets["user_followers"]
del tweets["user_friends"]

# %%
del tweets["user_verified"]
del tweets["hashtags"]
del tweets["source"]
del tweets["is_retweet"]

# %%
tweets.head(5)
# Out:
#                   date                                               text
# 0  2021-02-10 23:59:04  Blue Ridge Bank shares halted by NYSE after #b...
# 1  2021-02-10 23:58:48  😎 Today, that's this #Thursday, we will do a "...
# 2  2021-02-10 23:54:48  Guys evening, I have read this article about B...
# 3  2021-02-10 23:54:33  $BTC A big chance in a billion! Price: \487264...
# 4  2021-02-10 23:54:06  This network is secured by 9 508 nodes as of t...

# %%
tweets.to_csv("tweets.csv", index=False)

# %%
lemmatizer = WordNetLemmatizer()

# %%
tweets['text'] = tweets['text'].astype(str).apply(lambda x: re.sub('[^a-zA-Z0-9]+', ' ', x).lower())

# %%
stop_words = stopwords.words('english')

# %%
tweets['text'] = tweets['text'].astype(str).apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))

# %%
tweets.head(5)
# Out:
#                   date                                               text
# 0  2021-02-10 23:59:04  blue ridge bank shares halted nyse bitcoin atm...
# 1  2021-02-10 23:58:48  today thursday take 2 friend leowandersleb btc...
# 2  2021-02-10 23:54:48  guys evening read article btc would like share...
# 3  2021-02-10 23:54:33  btc big chance billion price 4872644 0 2021 02...
# 4  2021-02-10 23:54:06  network secured 9 508 nodes today soon biggest...

# %%
tweets['sentiment'] = tweets['text'].apply(lambda x: TextBlob(x).sentiment[0])

# %%
tweets['date'] = pd.to_datetime(tweets['date'])

# %%
tweets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2573255 entries, 0 to 2573254
# Data columns (total 2 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   date    datetime64[ns]
#  1   text    object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 39.3+ MB

# %%
tweets['date'].dt.date.min()

# %%
date_range = str(tweets['date'].dt.date.min()) + ' to ' + str(tweets['date'].dt.date.max())

# %%
tweets.head(100)
# Out:
#                    date                                               text  \
# 0   2021-02-10 23:59:04  blue ridge bank shares halted nyse bitcoin atm...
# 1   2021-02-10 23:58:48  today thursday take 2 friend leowandersleb btc...
# 2   2021-02-10 23:54:48  guys evening read article btc would like share...
# 3   2021-02-10 23:54:33  btc big chance billion price 4872644 0 2021 02...
# 4   2021-02-10 23:54:06  network secured 9 508 nodes today soon biggest...
# ..                  ...                                                ...
# 95  2021-02-10 23:10:02  bitcoin btc current price 45 161 73 1 hour 1 2...
# 96  2021-02-10 23:09:59  michael saylor advertising tactic called linki...
# 97  2021-02-10 23:09:39  prices update usd 1 hour btc 45081 8 0 18 eth ...
# 98  2021-02-10 23:09:18  added episode 25 insane 888eth 1 5m genesis la...
# 99  2021-02-10 23:08:14  ftm looking super amazing easily 400 bitcoin b...
#
#     sentiment
# 0    0.000000
# 1    0.000000
# 2    0.000000
# ...

# %%
price_df = pd.read_csv("bitstampUSD.csv")

# %%
price_df.head(5)
# Out:
#     Timestamp  Open  High   Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0  1325317920  4.39  4.39  4.39   4.39      0.455581                2.0
# 1  1325317980   NaN   NaN   NaN    NaN           NaN                NaN
# 2  1325318040   NaN   NaN   NaN    NaN           NaN                NaN
# 3  1325318100   NaN   NaN   NaN    NaN           NaN                NaN
# 4  1325318160   NaN   NaN   NaN    NaN           NaN                NaN
#
#    Weighted_Price
# 0            4.39
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
len(price_df)
# Out:
# 4727777

# %%
price_df['date'] = pd.to_datetime(price_df['Timestamp'], unit='s')

# %%
price_df.head(5)
# Out:
#     Timestamp  Open  High   Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0  1325317920  4.39  4.39  4.39   4.39      0.455581                2.0
# 1  1325317980   NaN   NaN   NaN    NaN           NaN                NaN
# 2  1325318040   NaN   NaN   NaN    NaN           NaN                NaN
# 3  1325318100   NaN   NaN   NaN    NaN           NaN                NaN
# 4  1325318160   NaN   NaN   NaN    NaN           NaN                NaN
#
#    Weighted_Price                date
# 0            4.39 2011-12-31 07:52:00
# 1             NaN 2011-12-31 07:53:00
# 2             NaN 2011-12-31 07:54:00
# 3             NaN 2011-12-31 07:55:00
# 4             NaN 2011-12-31 07:56:00

# %%
date_range = str(price_df['date'].dt.date.min()) + ' to ' + str(price_df['date'].dt.date.max())

# %%
print(date_range)
# Out:
# 2011-12-31 to 2020-12-31

# %%
tweets.sort_values(by=['date'], inplace=True, ascending=True)

# %%
tweets.head(5)
# Out:
#                       date                                               text  \
# 21523  2021-02-05 10:52:04  2 debunking 9 bitcoin myths patrick lowry cryp...
# 21524  2021-02-05 10:52:04  weekend read keen learn crypto assets check re...
# 21522  2021-02-05 10:52:06  4 bloomberg lp cryptooutlook 2021 mikemcglone1...
# 21521  2021-02-05 10:52:07  5 blockchain 50 2021 delrayman forbes forbescr...
# 21520  2021-02-05 10:52:26  reddcoin rdd reddcoin moon altcoin turnreddcoi...
#
#        sentiment
# 21523        0.0
# 21524        0.0
# 21522        0.0
# 21521        0.0
# 21520        0.0

# %%
len(tweets)
# Out:
# 2573255

# %%
tweets['date'] = pd.to_datetime(tweets['date'])
#date_range_tweets = str(tweets['date'].dt.date.min()) + ' to ' + str(tweets['date'].dt.date.max())

# %%
price_df.head(5)
# Out:
#     Timestamp  Open  High   Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0  1325317920  4.39  4.39  4.39   4.39      0.455581                2.0
# 1  1325317980   NaN   NaN   NaN    NaN           NaN                NaN
# 2  1325318040   NaN   NaN   NaN    NaN           NaN                NaN
# 3  1325318100   NaN   NaN   NaN    NaN           NaN                NaN
# 4  1325318160   NaN   NaN   NaN    NaN           NaN                NaN
#
#    Weighted_Price                date
# 0            4.39 2011-12-31 07:52:00
# 1             NaN 2011-12-31 07:53:00
# 2             NaN 2011-12-31 07:54:00
# 3             NaN 2011-12-31 07:55:00
# 4             NaN 2011-12-31 07:56:00

# %%
price_df.head(10)
# Out:
#     Timestamp  Open  High   Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0  1325317920  4.39  4.39  4.39   4.39      0.455581                2.0
# 1  1325317980   NaN   NaN   NaN    NaN           NaN                NaN
# 2  1325318040   NaN   NaN   NaN    NaN           NaN                NaN
# 3  1325318100   NaN   NaN   NaN    NaN           NaN                NaN
# 4  1325318160   NaN   NaN   NaN    NaN           NaN                NaN
# 5  1325318220   NaN   NaN   NaN    NaN           NaN                NaN
# 6  1325318280   NaN   NaN   NaN    NaN           NaN                NaN
# 7  1325318340   NaN   NaN   NaN    NaN           NaN                NaN
# 8  1325318400   NaN   NaN   NaN    NaN           NaN                NaN
# 9  1325318460   NaN   NaN   NaN    NaN           NaN                NaN
#
#    Weighted_Price                date
# 0            4.39 2011-12-31 07:52:00
# 1             NaN 2011-12-31 07:53:00
# 2             NaN 2011-12-31 07:54:00
# ...

# %%
price_df = price_df.iloc[8:]

# %%
price_df = price_df.reset_index(drop=True)

# %%
price_df.head(60)
# Out:
#      Timestamp  Open  High  Low  Close  Volume_(BTC)  Volume_(Currency)  \
# 0   1325318400   NaN   NaN  NaN    NaN           NaN                NaN
# 1   1325318460   NaN   NaN  NaN    NaN           NaN                NaN
# 2   1325318520   NaN   NaN  NaN    NaN           NaN                NaN
# 3   1325318580   NaN   NaN  NaN    NaN           NaN                NaN
# 4   1325318640   NaN   NaN  NaN    NaN           NaN                NaN
# 5   1325318700   NaN   NaN  NaN    NaN           NaN                NaN
# 6   1325318760   NaN   NaN  NaN    NaN           NaN                NaN
# 7   1325318820   NaN   NaN  NaN    NaN           NaN                NaN
# 8   1325318880   NaN   NaN  NaN    NaN           NaN                NaN
# 9   1325318940   NaN   NaN  NaN    NaN           NaN                NaN
# 10  1325319000   NaN   NaN  NaN    NaN           NaN                NaN
# 11  1325319060   NaN   NaN  NaN    NaN           NaN                NaN
# ...

# %%
def average(lst):
    return sum(lst) / len(lst)

# %%
df = pd.DataFrame(columns=["date","close_price"])

# %%
import math

# %%
previous_price = 4.39
size = len(price_df)
bitcoin_df = {}
i = 0
while i < size and i+60 < size:
    price = []
    for j in range(i, i+60):
        if not math.isnan(price_df["Close"][j]):
            price.append(price_df["Close"][j])
    if len(price) != 0:
        close_price = round(average(price), 2)
    else:
        close_price = previous_price
    data = {"date": price_df["date"][i], "close_price": previous_price}
    previous_price = close_price
    df = df.append(data, ignore_index=True)
    i = i + 60

# %%
len(df)
# Out:
# 78796

# %%
del df["data"]

# %%
df.head(5)
# Out:
#                  date  close_price
# 0 2011-12-31 08:00:00         4.39
# 1 2011-12-31 09:00:00         4.39
# 2 2011-12-31 10:00:00         4.39
# 3 2011-12-31 11:00:00         4.39
# 4 2011-12-31 12:00:00         4.39

# %%
df.to_csv("bitcoin_price_usd.csv", index=False)
